# %% [markdown]
# Write OOP classes to handle the following scenarios:
# 1. A user can create and view 2D coordinates
# 2. A user can find out the distance between 2 coordinates
# 3. A user can find find the distance of a coordinate from origin
# 4. A user can check if a point lies on a given line
# 5. A user can find the distance between a given 2D point and a given line
# 6. Also check if two lines are parallel or not (whether they intersect or not)

# %%
class Point:
    
    def __init__(self, x, y):
        self.x_cod = x
        self.y_cod = y

    def __str__(self):
        return f"<{self.x_cod}, {self.y_cod}>"

    def euclidean_distance(self, other):
        return ((self.x_cod - other.x_cod) ** 2 + (self.y_cod - other.y_cod) ** 2) ** 0.5

    def distance_from_origin(self):
        return self.euclidean_distance(Point(0, 0))

# %%
p1 = Point(0, 0)
print(p1)

p2 = Point(10, 10)
print(p2)

print(p1.euclidean_distance(p2))
print(p2.distance_from_origin())
# Out:
# <0, 0>
# <10, 10>
# 14.142135623730951
# 14.142135623730951

# %%
class Line:

    def __init__(self, A, B, C):
        self.A = A
        self.B = B
        self.C = C

    def __str__(self):
        return f"{self.A}X + {self.B}Y + {self.C} = 0"
    
    def point_on_line(self, p: Point) -> bool:
        val = self.A * p.x_cod + self.B * p.y_cod + self.C
        if val == 0:
            return "Lies on the Line"
        else:
            return "Does not lie on the Line"
        
    def shortest_distance(self, p: Point) -> int:
        return abs(self.A * p.x_cod + self.B * p.y_cod + self.C) / ((self.A ** 2 + self.B ** 2) ** 0.5)
    
    def check_parallel(self, l: Line) -> bool:
        # instead check for A1​ * B2​ = A2 * ​B1​
        # slope1 = (-self.A / self.B)
        # slope2 = (-l.A / l.B)
        return self.A * l.B == l.A * self.B
    
    def check_coincident(self, l: "Line") -> bool:
        return (
            self.A * l.B == l.A * self.B and
            self.A * l.C == l.A * self.C and
            self.B * l.C == l.B * self.C
        )

# %%
l1 = Line(1, 1, -2)
print(l1)
print(l1.point_on_line(Point(1, 1)))
print(l1.point_on_line(Point(0, 1)))
# Out:
# 1X + 1Y + -2 = 0
# Lies on the Line
# Does not lie on the Line

# %%
print(l1.shortest_distance(Point(1, 10)))
# Out:
# 6.363961030678928

# %%
l2 = Line(2, 3, 5)
l3 = Line(2, 3, -10)
l4 = Line(2, 8, 7)

print(l2.check_parallel(l3))
print(l2.check_parallel(l4))
# Out:
# True
# False

# %% [markdown]
# ## How objects access attributes

# %%
class Person:
    def __init__(self, name, country):
        self.name = name 
        self.country = country

    def greet(self):
        if self.country == 'India':
            print("Namaste! ", self.name)
        else:
            print("Hello! ", self.name)

# %%
p = Person('Ram', 'India')
p.greet()
p.name
# Out:
# Namaste!  Ram
# 'Ram'

# %%
p.gender
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 p.gender
#
# AttributeError: 'Person' object has no attribute 'gender'

# %%
p.gender = 'Male'

# %%
p.gender
# Out:
# 'Male'

# %% [markdown]
# ## Reference Variable
#
# 1. Reference Variables
# 2. Reference variables hold the objects
# 3. We can create objects without reference variable as well
# 4. An object can have multiple reference variables
# 5. Assigning a new reference variable to an existing object does not create a new object

# %%
# object without a reference

class Person:
    def __init__(self):
        self.name = 'Nitish'
        self.gender = 'Male'

# creating an object without reference
Person()

# multiple reference
p = Person()
q = p        # aliasing
# p is not our object, p and q are just the reference variables which store the reference/ address to the real object created in the memory

# %%
# multiple reference

print(id(p))
print(id(q))
# Out:
# 4661529168
# 4661529168

# %%
print(p.name)
print(q.name)

q.name = 'Ankit'

print(p.name)
print(q.name)
# Out:
# Nitish
# Nitish
# Ankit
# Ankit

# %% [markdown]
# ## Pass by Reference

# %%
class Person:
    def __init__(self, name, gender):
        self.name = name
        self.gender = gender

#outside the class


# here p is just a reference which contains the address of the object, therefore the value for id(p) in the both the places will be same 
# this is only possible because in python, be default the user defined data types i.e., are mutable
# we can also make it immutable if we want
# if it was immutable then making changes to the object would result in creation of a new object.
def greet(p: Person) -> Person:
    # print(id(p))
    # print(f"Hi! My name is {p.name} and I am a {p.gender}")
    p.name = 'Ankit'
    # print(p.name)
    return p

p = Person('Nitish', 'Male')

print(id(p))
p1 = greet(p)
print(id(p1))
# print(p.name)
# Out:
# 4371319840
# 4371319840

# %% [markdown]
# ## Encapsulation
#
# for every attribute -> make it private and create two getters and setters, then you can add all the functionalities you want around the values that will be input by user.

# %%
class Person:

    def __init__(self, name, country):
        self.name = name
        self.country = country
    
p1 = Person('Nitish', 'India')
p2 = Person('Steve', 'Australia')

print(p1.name)
print(p2.name)
# Out:
# Nitish
# Steve

# %%
class Atm:

  # constructor(special function)->superpower -> 
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0
    #self.menu()

  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %%
obj = Atm()
# Out:
# 4371027664

# %%
obj.create_pin()
obj._Atm__balance = 'hehehe'
# Out:
# pin created successfully

# %%
obj.withdraw()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 obj.withdraw()
#
# Cell In[1], line 72, in Atm.withdraw(self)
#      69 if user_pin == self.pin:
#      70   # allow to withdraw
#      71   amount = int(input('enter the amount'))
# ---> 72   if amount <= self.__balance:
#      73     self.__balance = self.__balance - amount
#      74     print('withdrawl successful.balance is',self.__balance)
#
# TypeError: '<=' not supported between instances of 'int' and 'str'

# %%
obj.get_balance()
# Out:
# 'hehehe'

# %%
obj.set_balance(10000)

# %%
obj.get_balance()
# Out:
# 10000

# %%
obj.set_balance('hehehe')
# Out:
# beta bahot maarenge

# %% [markdown]
# ### Collection of Objects

# %%
# obj = Person("Arpit", "Male")

# is equivalent to 

# obj = Person.__new__(Person)
# Person.__init__(obj, "Arpit", "Male")

# %%
# list of objects

class Person:

    def __init__(self, name, gender) -> None:
        self.name = name
        self.gender = gender

# %%
p1 = Person('Nitish', 'Male')
p2 = Person('Ankit', 'Male')
p3 = Person('Ankita', 'Female')

l = [p1, p2, p3]

for i in l:
    print(i.name, i.gender)
# Out:
# Nitish Male
# Ankit Male
# Ankita Female

# %%
d = {
    'p1': p1,
    'p2': p2,
    'p3': p3,
}

for i in d.keys():
    print(i, d[i], d[i].name)
# Out:
# p1 <__main__.Person object at 0x104b6ae00> Nitish
# p2 <__main__.Person object at 0x104b6acf0> Ankit
# p3 <__main__.Person object at 0x10592f450> Ankita

# %% [markdown]
# ## Static Variables (Vs Instance Variables)

# %%
class Atm:

  # static variable
  __counter = 1

  # constructor(special function)->superpower -> 
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0
    #self.menu()
    self.cid = Atm.__counter
    Atm.__counter
  
  # self not needed
  def get_counter():
    return Atm.counter
  
  @staticmethod
  def set_counter(val):
    Atm.counter = val

  # utility functions
  @staticmethod
  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %%
# Atm.counter = 'hehehe'     # make it private make it from counter to __counter

# otherwise 
# c = Atm()
# will give error

# %%
c1 = Atm()
# Out:
# 4390798400

# %%
c1.get_counter()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 c1.get_counter()
#
# TypeError: Atm.get_counter() takes 0 positional arguments but 1 was given

# %%
c2 = Atm()
# Out:
# 4579423760

# %%
c3 = Atm()
# Out:
# 4579424720

# %%
# using an instance variable, we cannot implement a counter

print(c1.cid)
print(c2.cid)
print(c3.cid)
# Out:
# 1
# 2
# 3

# %%
# the value of static variable is same for every intance of the class
# the value of instance variable is diff for every instance
